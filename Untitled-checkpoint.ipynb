# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.utils import to_categorical

class_names = {
    0: "dog",
    1: "cat",
    2: "Horse"
}

X_train = np.loadtxt('input.csv', delimiter=',')
Y_train = np.loadtxt('labels.csv', delimiter=',')

X_test = np.loadtxt('input_test.csv', delimiter=',')
Y_test = np.loadtxt('labels_test.csv', delimiter=',')

X_train = X_train.reshape(len(X_train), 100, 100, 3)
X_test = X_test.reshape(len(X_test), 100, 100, 3)

X_train = X_train / 255.0
X_test = X_test / 255.0
s
Y_train = Y_train.reshape(len(Y_train), 1)
Y_test = Y_test.reshape(len(Y_test), 1)

num_classes = len(np.unique(Y_train))
Y_train = to_categorical(Y_train, num_classes)
Y_test = to_categorical(Y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=10, batch_size=32, validation_split=0.2)


loss, accuracy = model.evaluate(X_test, Y_test)
print(f"\n Test Accuracy: {accuracy:.2f}")

model.save("image_classifier_model.h5")
print(" Model saved successfully!")

idx = random.randint(0, len(X_train) - 1)
label_index = np.argmax(Y_train[idx])

plt.imshow(X_train[idx])
plt.title(f"Label: {class_names[label_index]}")
plt.axis('off')
plt.show()

model = load_model("image_classifier_model.h5")

image_path = "test.jpg"
img = cv2.imread(image_path)

if img is None:
    print(f" Error: Image file '{image_path}' not found.")
else:
    img = cv2.resize(img, (100, 100))
    img = img.astype("float32") / 255.0
    img = img.reshape(1, 100, 100, 3)

    pred = model.predict(img)
    class_index = np.argmax(pred)

    print(f"\n Predicted Class Number: {class_index}")
    print(f" Predicted Class Name: {class_names[class_index]}")
# Out:
# C:\Users\p2005\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.5652 - loss: 0.8534 - val_accuracy: 0.0000e+00 - val_loss: 1.1029
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.6294 - loss: 0.6318 - val_accuracy: 0.0000e+00 - val_loss: 1.3328
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.6685 - loss: 0.5913 - val_accuracy: 0.3300 - val_loss: 0.9513
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.7611 - loss: 0.4998 - val_accuracy: 0.4075 - val_loss: 1.0597
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.8266 - loss: 0.4120 - val_accuracy: 0.5675 - val_loss: 0.8580
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8716 - loss: 0.3132 - val_accuracy: 0.4375 - val_loss: 1.3046
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.9300 - loss: 0.2101 - val_accuracy: 0.6250 - val_loss: 1.0055
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.9524 - loss: 0.1438 - val_accuracy: 0.5525 - val_loss: 1.5385
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.9682 - loss: 0.1018 - val_accuracy: 0.5625 - val_loss: 1.6870
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9804 - loss: 0.0561 - val_accuracy: 0.5800 - val_loss: 1.7934
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6980 - loss: 1.0666
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#  Test Accuracy: 0.67
#  Model saved successfully!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  Error: Image file 'test.jpg' not found.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 98, 98, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 49, 49, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 47, 47, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 33856)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       4,333,696 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,353,348 (16.61 MB)
#  Trainable params: 4,353,346 (16.61 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# !pip install pydot
# !pip install graphviz
# Out:
# Requirement already satisfied: pydot in c:\users\p2005\appdata\local\programs\python\python311\lib\site-packages (4.0.1)
# Requirement already satisfied: pyparsing>=3.1.0 in c:\users\p2005\appdata\local\programs\python\python311\lib\site-packages (from pydot) (3.2.3)
# Requirement already satisfied: graphviz in c:\users\p2005\appdata\local\programs\python\python311\lib\site-packages (0.21)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
model.save("image_classifier_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
